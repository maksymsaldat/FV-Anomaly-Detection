# %% [markdown]
# # 1. Carga del dataset preprocesado

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv(
    "../data/plant1_preprocessed.csv"
)

dataset.head()
# Out:
#              DATE_TIME  AC_POWER  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 0  2020-05-15 00:00:00       0.0            25.184316           22.857507
# 1  2020-05-15 00:15:00       0.0            25.084589           22.761668
# 2  2020-05-15 00:30:00       0.0            24.935753           22.592306
# 3  2020-05-15 00:45:00       0.0            24.846130           22.360852
# 4  2020-05-15 01:00:00       0.0            24.621525           22.165423
#
#    IRRADIATION  HOUR
# 0          0.0     0
# 1          0.0     0
# 2          0.0     0
# 3          0.0     0
# 4          0.0     1

# %% [markdown]
# # 2. Eliminación de registros nocturnos

# %%
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3157 entries, 0 to 3156
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   DATE_TIME            3157 non-null   str
#  1   AC_POWER             3157 non-null   float64
#  2   AMBIENT_TEMPERATURE  3157 non-null   float64
#  3   MODULE_TEMPERATURE   3157 non-null   float64
#  4   IRRADIATION          3157 non-null   float64
#  5   HOUR                 3157 non-null   int64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 148.1 KB

# %%
dataset.shape
# Out:
# (3157, 6)

# %%
dataset_daylight = dataset[
    dataset["IRRADIATION"] > 0
].copy()

dataset_daylight.shape
# Out:
# (1754, 6)

# %%
dataset_daylight.describe()
# Out:
#            AC_POWER  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION  \
# count   1754.000000          1754.000000         1754.000000  1754.000000
# mean   12067.930442            27.448244           39.013366     0.414159
# std     8278.014373             3.228135           11.449517     0.295328
# min        0.000000            20.398505           18.242308     0.000015
# 25%     4220.645536            25.080542           28.887418     0.139471
# 50%    12459.201488            27.565305           39.604553     0.406717
# 75%    18833.751339            29.741352           47.945945     0.638485
# max    29150.212499            35.252486           65.545714     1.221652
#
#               HOUR
# count  1754.000000
# mean     11.875143
# std       3.793715
# min       5.000000
# 25%       9.000000
# 50%      12.000000
# 75%      15.000000
# max      19.000000

# %% [markdown]
# # 3. Selección de variables

# %%
y = dataset_daylight["AC_POWER"]

# %%
X = dataset_daylight[
    [
        "AMBIENT_TEMPERATURE",
        "MODULE_TEMPERATURE",
        "IRRADIATION",
        "HOUR"
    ]
]

# %%
X.head()
# Out:
#     AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  IRRADIATION  HOUR
# 23            24.289211           23.096692     0.000863     5
# 24            24.088446           22.206757     0.005887     6
# 25            24.011635           22.353459     0.022282     6
# 26            23.976731           22.893282     0.049410     6
# 27            24.218990           24.442444     0.095394     6

# %%
y.head()
# Out:
# 23       0.000000
# 24      90.929167
# 25     593.338690
# 26    1480.194643
# 27    2790.448214
# Name: AC_POWER, dtype: float64

# %%
print("X:", X.shape)
print("y:", y.shape)
# Out:
# X: (1754, 4)
# y: (1754,)

# %% [markdown]
# # 4. División entrenamiento-prueba interna (70%/30% de Plant 1)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %%
print("X_train:", X_train.shape)
print("X_test:", X_test.shape)

print("y_train:", y_train.shape)
print("y_test:", y_test.shape)
# Out:
# X_train: (1227, 4)
# X_test: (527, 4)
# y_train: (1227,)
# y_test: (527,)

# %% [markdown]
# # 5. Entrenamiento del modelo Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf.predict(X_test)

# %% [markdown]
# # 6. Evaluación del modelo

# %%
from sklearn.metrics import (
    mean_absolute_error,
    mean_squared_error,
    r2_score
)

mae = mean_absolute_error(y_test, y_pred)

rmse = np.sqrt(
    mean_squared_error(y_test, y_pred)
)

r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("RMSE:", rmse)
print("R²:", r2)
# Out:
# MAE: 486.2249330621819
# RMSE: 783.6799667794394
# R²: 0.9909719689206529

# %% [markdown]
# # 7. Visualización de resultados

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    y_test,
    y_pred,
    alpha=0.5
)

plt.xlabel("AC_POWER real")
plt.ylabel("AC_POWER predicha")
plt.title("Producción real vs producción predicha")

plt.show()

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Variable": X.columns,
    "Importancia": rf.feature_importances_
})

feature_importance.sort_values(
    by="Importancia",
    ascending=False
)
# Out:
#               Variable  Importancia
# 2          IRRADIATION     0.994110
# 1   MODULE_TEMPERATURE     0.002507
# 0  AMBIENT_TEMPERATURE     0.002082
# 3                 HOUR     0.001300

# %%
feature_importance.sort_values(
    by="Importancia",
    ascending=False
).plot(
    x="Variable",
    y="Importancia",
    kind="bar"
)

plt.show()

# %% [markdown]
# # 8. Exportación del modelo

# %%
import joblib

joblib.dump(
    rf,
    "../models/random_forest_plant1.pkl"
)
# Out:
# ['../models/random_forest_plant1.pkl']

# %% [markdown]
# # 9. Validación externa con Plant 2

# %%
plant2 = pd.read_csv(
    "../data/plant2_preprocessed.csv"
)

plant2.head()
# Out:
#              DATE_TIME  AC_POWER  AMBIENT_TEMPERATURE  MODULE_TEMPERATURE  \
# 0  2020-05-15 00:00:00       0.0            27.004764           25.060789
# 1  2020-05-15 00:15:00       0.0            26.880811           24.421869
# 2  2020-05-15 00:30:00       0.0            26.682055           24.427290
# 3  2020-05-15 00:45:00       0.0            26.500589           24.420678
# 4  2020-05-15 01:00:00       0.0            26.596148           25.088210
#
#    IRRADIATION  HOUR
# 0          0.0     0
# 1          0.0     0
# 2          0.0     0
# 3          0.0     0
# 4          0.0     1

# %%
plant2_daylight = plant2[
    plant2["IRRADIATION"] > 0
].copy()

print(plant2_daylight.shape)
# Out:
# (1862, 6)

# %%
X2 = plant2_daylight[
    [
        "AMBIENT_TEMPERATURE",
        "MODULE_TEMPERATURE",
        "IRRADIATION",
        "HOUR"
    ]
]

y2 = plant2_daylight["AC_POWER"]

# %%
y2_pred = rf.predict(X2)

# %%
mae2 = mean_absolute_error(y2, y2_pred)

rmse2 = np.sqrt(
    mean_squared_error(y2, y2_pred)
)

r2_2 = r2_score(y2, y2_pred)

print("MAE:", mae2)
print("RMSE:", rmse2)
print("R²:", r2_2)
# Out:
# MAE: 3207.813310049959
# RMSE: 5549.028437325891
# R²: 0.16451418260414263

# %%
plt.figure(figsize=(10,6))

plt.scatter(
    y2,
    y2_pred,
    alpha=0.5
)

plt.xlabel("AC_POWER real")
plt.ylabel("AC_POWER predicha")
plt.title("Validación externa - Plant 2")

plt.show()

# %%
plant2_daylight["AC_POWER"].describe()
# Out:
# count     1862.000000
# mean      8772.292980
# std       6072.451589
# min          0.000000
# 25%       2748.819286
# 50%       9703.754048
# 75%      13748.358333
# max      25979.760476
# Name: AC_POWER, dtype: float64
